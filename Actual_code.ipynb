# %%
import pandas as pd

df = pd.read_csv("clean_customer_churn_dataset.csv")

df
# Out:
#       customer_id   age gender subscription_type  tenure_months  \
# 0      85714623.0  34.0      M          Standard           12.0
# 1      29547381.0  28.0      F           Premium           24.0
# 2      33416294.0  45.0      M          Standard            9.0
# 3      19486372.0  55.0      F           Premium           36.0
# 4      87126314.0  22.0      M          Standard            2.0
# ...           ...   ...    ...               ...            ...
# 1367   86713409.0  22.0      F          Standard            1.0
# 1368   48152036.0  32.0      M             Basic            9.0
# 1369   39164782.0  26.0      F           Premium            3.0
# 1370   29908417.0  48.0      M          Standard           37.0
# 1371   51104362.0  19.0      F             Basic            2.0
#
#       monthly_spend  support_tickets  avg_session_time  \
# 0             45.50              3.0              30.5
# 1            150.00              1.0              75.2
# 2             50.00              6.0              35.0
# 3            180.00              0.0              90.0
# 4             30.00              8.0              20.0
# ...             ...              ...               ...
# 1367          12.50             15.0              10.5
# 1368          27.30              7.0              24.0
# 1369         135.00              1.0             100.0
# 1370          99.99              2.0              85.0
# 1371          22.00             11.0              13.0
#
#                            customer_feedback  churn
# 0     Great service but needs more features.    0.0
# 1                Love the content offerings!    0.0
# 2          Not bad, but slow response times.    1.0
# 3             Best service I've used so far!    0.0
# 4             I might consider leaving soon.    1.0
# ...                                      ...    ...
# 1367              Not happy with the service    1.0
# 1368                          It's just okay    1.0
# 1369            Very nice experience overall    0.0
# 1370               Service has been reliable    0.0
# 1371                  Not happy with the app    1.0
#
# [1372 rows x 10 columns]

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# Load model once (fast)
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

def get_embedding(text: str) -> np.ndarray:
    """
    Returns a vector embedding for the input string
    using all-MiniLM-L6-v2.
    """
    embedding = model.encode(text, convert_to_numpy=True)
    return embedding

# %%
df["customer_feedback(vector)"] = df["customer_feedback"].apply(get_embedding)
df
# Out:
#       customer_id   age gender subscription_type  tenure_months  \
# 0      85714623.0  34.0      M          Standard           12.0
# 1      29547381.0  28.0      F           Premium           24.0
# 2      33416294.0  45.0      M          Standard            9.0
# 3      19486372.0  55.0      F           Premium           36.0
# 4      87126314.0  22.0      M          Standard            2.0
# ...           ...   ...    ...               ...            ...
# 1367   86713409.0  22.0      F          Standard            1.0
# 1368   48152036.0  32.0      M             Basic            9.0
# 1369   39164782.0  26.0      F           Premium            3.0
# 1370   29908417.0  48.0      M          Standard           37.0
# 1371   51104362.0  19.0      F             Basic            2.0
#
#       monthly_spend  support_tickets  avg_session_time  \
# 0             45.50              3.0              30.5
# 1            150.00              1.0              75.2
# 2             50.00              6.0              35.0
# 3            180.00              0.0              90.0
# 4             30.00              8.0              20.0
# ...             ...              ...               ...
# 1367          12.50             15.0              10.5
# 1368          27.30              7.0              24.0
# 1369         135.00              1.0             100.0
# 1370          99.99              2.0              85.0
# 1371          22.00             11.0              13.0
#
#                            customer_feedback  churn  \
# 0     Great service but needs more features.    0.0
# 1                Love the content offerings!    0.0
# 2          Not bad, but slow response times.    1.0
# 3             Best service I've used so far!    0.0
# 4             I might consider leaving soon.    1.0
# ...                                      ...    ...
# 1367              Not happy with the service    1.0
# 1368                          It's just okay    1.0
# 1369            Very nice experience overall    0.0
# 1370               Service has been reliable    0.0
# 1371                  Not happy with the app    1.0
#
#                               customer_feedback(vector)
# 0     [-0.023977788, -0.035339907, 0.022685938, -0.1...
# 1     [-0.015775949, -0.08186792, 0.03367149, -0.009...
# 2     [-0.05630388, -0.048019897, -0.0036284912, 0.0...
# 3     [-0.10727816, -0.031212743, 0.0028661534, -0.0...
# 4     [0.02378889, -0.10755215, 0.06179209, 0.039435...
# ...                                                 ...
# 1367  [-0.05860101, 0.06611584, 0.028202888, -0.0434...
# 1368  [-0.033073783, -0.021272624, 0.008105284, -0.0...
# 1369  [-0.014699893, 0.10536847, 0.07130461, 0.01225...
# 1370  [-0.11329235, -0.019851938, 0.0052584913, -0.0...
# 1371  [-0.037289277, 0.055136304, 0.0013100117, -0.0...
#
# [1372 rows x 11 columns]
